# %%
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import string
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as sts
fuzzy_csv = '../Resources/fuzzy_df.csv'
billboard_csv = '../Resources/billboard_lyrics_1964-2015.csv'
song_data_csv = '../Resources/song_data.csv'

# %%
fuzzy_df = pd.read_csv(fuzzy_csv)
billboard_df = pd.read_csv(billboard_csv, encoding = 'ISO-8859-1')
song_data_df = pd.read_csv(song_data_csv)

# %%
fuzzy_df = fuzzy_df.rename(columns={'Unnamed: 0':'Order'})

# %%
fuzzy_df.head()
# Out:
#                                   Song_Name  \
# 0                               wooly bully
# 1  i cant help myself sugar pie honey bunch
# 2                i cant get no satisfaction
# 3                       you were on my mind
# 4              youve lost that lovin feelin
#
#                                Matched_Name  Ratio_Value  Song_List_Index
# 0                               only lonely           64             3209
# 1  i cant help myself sugar pie honey bunch          100             3863
# 2                i cant get no satisfaction          100              251
# 3                          youre on my mind           91            11156
# 4                        youve got the love           70             1959

# %%
song_data_df.columns
# Out:
# Index(['song_name', 'song_popularity', 'song_duration_ms', 'acousticness',
#        'danceability', 'energy', 'instrumentalness', 'key', 'liveness',
#        'loudness', 'audio_mode', 'speechiness', 'tempo', 'time_signature',
#        'audio_valence'],
#       dtype='object')

# %%
# adding Song List Index column to merge with the fuzzy_df
song_data_df = song_data_df.reset_index()

# %%
song_data_df['Song_List_Index'] = range(len(song_data_df))

# %%
song_data_df
# Out:
#        index                   song_name  song_popularity  song_duration_ms  \
# 0          0  Boulevard of Broken Dreams               73            262333
# 1          1                  In The End               66            216933
# 2          2           Seven Nation Army               76            231733
# 3          3                  By The Way               74            216933
# 4          4           How You Remind Me               56            223826
# ...      ...                         ...              ...               ...
# 18830  18830              Let It Breathe               60            159645
# 18831  18831                     Answers               60            205666
# 18832  18832      Sudden Love (Acoustic)               23            182211
# 18833  18833           Gentle on My Mind               55            352280
# 18834  18834                    Up to Me               60            193533
#
#        acousticness  danceability  energy  instrumentalness  key  liveness  \
# 0          0.005520         0.496   0.682          0.000029    8    0.0589
# 1          0.010300         0.542   0.853          0.000000    3    0.1080
# 2          0.008170         0.737   0.463          0.447000    0    0.2550
# 3          0.026400         0.451   0.970          0.003550    0    0.1020
# 4          0.000954         0.447   0.766          0.000000   10    0.1130
# ...             ...           ...     ...               ...  ...       ...
# 18830      0.893000         0.500   0.151          0.000065   11    0.1110
# 18831      0.765000         0.495   0.161          0.000001   11    0.1050
# 18832      0.847000         0.719   0.325          0.000000    0    0.1250
# 18833      0.945000         0.488   0.326          0.015700    3    0.1190
# 18834      0.911000         0.640   0.381          0.000254    4    0.1040
#
#        loudness  audio_mode  speechiness    tempo  time_signature  \
# 0        -4.095           1       0.0294  167.060               4
# 1        -6.407           0       0.0498  105.256               4
# 2        -7.828           1       0.0792  123.881               4
# 3        -4.938           1       0.1070  122.444               4
# 4        -5.065           1       0.0313  172.011               4
# ...         ...         ...          ...      ...             ...
# 18830   -16.107           1       0.0348  113.969               4
# 18831   -14.078           0       0.0301   94.286               4
# 18832   -12.222           1       0.0355  130.534               4
# 18833   -12.020           1       0.0328  106.063               4
# 18834   -11.790           1       0.0302   91.490               4
#
#        audio_valence  Song_List_Index
# 0              0.474                0
# 1              0.370                1
# 2              0.324                2
# 3              0.198                3
# 4              0.574                4
# ...              ...              ...
# 18830          0.300            18830
# 18831          0.265            18831
# 18832          0.286            18832
# 18833          0.323            18833
# 18834          0.581            18834
#
# [18835 rows x 17 columns]

# %%
song_data_df = song_data_df.drop(columns={'song_popularity','song_duration_ms'})

# %%
song_data_df.head()
# Out:
#    index                   song_name  acousticness  danceability  energy  \
# 0      0  Boulevard of Broken Dreams      0.005520         0.496   0.682
# 1      1                  In The End      0.010300         0.542   0.853
# 2      2           Seven Nation Army      0.008170         0.737   0.463
# 3      3                  By The Way      0.026400         0.451   0.970
# 4      4           How You Remind Me      0.000954         0.447   0.766
#
#    instrumentalness  key  liveness  loudness  audio_mode  speechiness  \
# 0          0.000029    8    0.0589    -4.095           1       0.0294
# 1          0.000000    3    0.1080    -6.407           0       0.0498
# 2          0.447000    0    0.2550    -7.828           1       0.0792
# 3          0.003550    0    0.1020    -4.938           1       0.1070
# 4          0.000000   10    0.1130    -5.065           1       0.0313
#
#      tempo  time_signature  audio_valence  Song_List_Index
# 0  167.060               4          0.474                0
# 1  105.256               4          0.370                1
# 2  123.881               4          0.324                2
# 3  122.444               4          0.198                3
# 4  172.011               4          0.574                4

# %%
# merging
matched_df = pd.merge(fuzzy_df,song_data_df,on='Song_List_Index')

# %%
matched_df
# Out:
#                                      Song_Name  \
# 0                                  wooly bully
# 1                            youre only lonely
# 2                              only the lonely
# 3     i cant help myself sugar pie honey bunch
# 4                   i cant get no satisfaction
# ...                                        ...
# 5095                                      here
# 5096                                     waves
# 5097                                 el perdon
# 5098                             night changes
# 5099                              back to back
#
#                                   Matched_Name  Ratio_Value  Song_List_Index  \
# 0                                  only lonely           64             3209
# 1                                  only lonely           79             3209
# 2                                  only lonely           85             3209
# 3     i cant help myself sugar pie honey bunch          100             3863
# 4                   i cant get no satisfaction          100              251
# ...                                        ...          ...              ...
# 5095                                     where           89             7203
# 5096                                     waves          100             7346
# 5097                                 el perdón           89            10269
# 5098                               dont change           75              746
# 5099                              back to back          100             3684
#
#       index                                     song_name  acousticness  \
# 0      3209                                   Only Lonely      0.898000
# 1      3209                                   Only Lonely      0.898000
# 2      3209                                   Only Lonely      0.898000
# 3      3863  I Can't Help Myself (Sugar Pie, Honey Bunch)      0.245000
# 4       251                 (I Can't Get No) Satisfaction      0.000380
# ...     ...                                           ...           ...
# 5095   7203                                         where      0.760000
# 5096   7346                                         Waves      0.039100
# 5097  10269                                     El Perdón      0.446000
# 5098    746                                  Don't Change      0.000059
# 5099   3684                                  Back To Back      0.008980
#
#       danceability  energy  instrumentalness  key  liveness  loudness  \
# 0            0.412   0.276          0.000372    7    0.0955   -11.711
# 1            0.412   0.276          0.000372    7    0.0955   -11.711
# 2            0.412   0.276          0.000372    7    0.0955   -11.711
# 3            0.667   0.599          0.000000    0    0.1070    -8.894
# 4            0.735   0.820          0.057200    2    0.0983    -8.554
# ...            ...     ...               ...  ...       ...       ...
# 5095         0.767   0.330          0.758000    5    0.5970   -12.559
# 5096         0.571   0.573          0.000009   10    0.3310    -4.533
# 5097         0.628   0.690          0.000000    8    0.1120    -5.828
# 5098         0.206   0.810          0.064400    9    0.0855    -6.492
# 5099         0.635   0.472          0.000000    8    0.1170    -3.869
#
#       audio_mode  speechiness    tempo  time_signature  audio_valence
# 0              1       0.0296   90.781               4         0.2140
# 1              1       0.0296   90.781               4         0.2140
# 2              1       0.0296   90.781               4         0.2140
# 3              1       0.0291  127.935               4         0.9710
# 4              1       0.0494  135.586               4         0.8590
# ...          ...          ...      ...             ...            ...
# 5095           0       0.0429  121.901               3         0.1950
# 5096           1       0.0383   96.122               4         0.0542
# 5097           1       0.0511  179.911               4         0.6620
# 5098           1       0.0423  163.552               4         0.1550
# 5099           0       0.5110  174.008               4         0.3730
#
# [5100 rows x 18 columns]

# %%
matched_df = matched_df.sort_values('Unnamed: 0').reset_index(inplace=False, drop=False)
matched_df
# Out:
#       level_0  Unnamed: 0                                 Song Name  \
# 0           0           0                               wooly bully
# 1           3           1  i cant help myself sugar pie honey bunch
# 2           4           2                i cant get no satisfaction
# 3           6           3                       you were on my mind
# 4           9           4              youve lost that lovin feelin
# ...       ...         ...                                       ...
# 5095     5097        5095                                 el perdon
# 5096     2265        5096                                 she knows
# 5097     5098        5097                             night changes
# 5098     5099        5098                              back to back
# 5099     2097        5099                     how deep is your love
#
#                                   Matched Name  Ratio Value  Song List Index  \
# 0                                  only lonely           64             3209
# 1     i cant help myself sugar pie honey bunch          100             3863
# 2                   i cant get no satisfaction          100              251
# 3                             youre on my mind           91            11156
# 4                           youve got the love           70             1959
# ...                                        ...          ...              ...
# 5095                                 el perdón           89            10269
# 5096                              heaven knows           76            10584
# 5097                               dont change           75              746
# 5098                              back to back          100             3684
# 5099                     how deep is your love          100            13160
#
#       index                                     song_name  acousticness  \
# 0      3209                                   Only Lonely      0.898000
# 1      3863  I Can't Help Myself (Sugar Pie, Honey Bunch)      0.245000
# 2       251                 (I Can't Get No) Satisfaction      0.000380
# 3     11156                             You're on My Mind      0.814000
# 4      1959                           You've Got The Love      0.004070
# ...     ...                                           ...           ...
# 5095  10269                                     El Perdón      0.446000
# 5096  10584                                  Heaven Knows      0.035100
# 5097    746                                  Don't Change      0.000059
# 5098   3684                                  Back To Back      0.008980
# 5099  13160                         How Deep Is Your Love      0.038900
#
#       danceability  energy  instrumentalness  key  liveness  loudness  \
# 0            0.412   0.276          0.000372    7    0.0955   -11.711
# 1            0.667   0.599          0.000000    0    0.1070    -8.894
# 2            0.735   0.820          0.057200    2    0.0983    -8.554
# 3            0.651   0.128          0.908000    2    0.0596   -14.998
# 4            0.571   0.708          0.000000    6    0.1250    -4.740
# ...            ...     ...               ...  ...       ...       ...
# 5095         0.628   0.690          0.000000    8    0.1120    -5.828
# 5096         0.750   0.564          0.000069    9    0.1120    -7.956
# 5097         0.206   0.810          0.064400    9    0.0855    -6.492
# 5098         0.635   0.472          0.000000    8    0.1170    -3.869
# 5099         0.738   0.868          0.001710   11    0.3880    -4.373
#
#       audio_mode  speechiness    tempo  time_signature  audio_valence
# 0              1       0.0296   90.781               4          0.214
# 1              1       0.0291  127.935               4          0.971
# 2              1       0.0494  135.586               4          0.859
# 3              1       0.0511  160.001               4          0.238
# 4              1       0.0329  109.899               4          0.398
# ...          ...          ...      ...             ...            ...
# 5095           1       0.0511  179.911               4          0.662
# 5096           0       0.0462   96.969               4          0.264
# 5097           1       0.0423  163.552               4          0.155
# 5098           0       0.5110  174.008               4          0.373
# 5099           0       0.0731  122.003               4          0.336
#
# [5100 rows x 20 columns]

# %%
matched_df.rename(columns={'Unnamed: 0':'order'}).drop(columns='level_0')
# Out:
#                                      Song_Name  \
# 0                                  wooly bully
# 1                            youre only lonely
# 2                              only the lonely
# 3     i cant help myself sugar pie honey bunch
# 4                   i cant get no satisfaction
# ...                                        ...
# 5095                                      here
# 5096                                     waves
# 5097                                 el perdon
# 5098                             night changes
# 5099                              back to back
#
#                                   Matched_Name  Ratio_Value  Song_List_Index  \
# 0                                  only lonely           64             3209
# 1                                  only lonely           79             3209
# 2                                  only lonely           85             3209
# 3     i cant help myself sugar pie honey bunch          100             3863
# 4                   i cant get no satisfaction          100              251
# ...                                        ...          ...              ...
# 5095                                     where           89             7203
# 5096                                     waves          100             7346
# 5097                                 el perdón           89            10269
# 5098                               dont change           75              746
# 5099                              back to back          100             3684
#
#       index                                     song_name  acousticness  \
# 0      3209                                   Only Lonely      0.898000
# 1      3209                                   Only Lonely      0.898000
# 2      3209                                   Only Lonely      0.898000
# 3      3863  I Can't Help Myself (Sugar Pie, Honey Bunch)      0.245000
# 4       251                 (I Can't Get No) Satisfaction      0.000380
# ...     ...                                           ...           ...
# 5095   7203                                         where      0.760000
# 5096   7346                                         Waves      0.039100
# 5097  10269                                     El Perdón      0.446000
# 5098    746                                  Don't Change      0.000059
# 5099   3684                                  Back To Back      0.008980
#
#       danceability  energy  instrumentalness  key  liveness  loudness  \
# 0            0.412   0.276          0.000372    7    0.0955   -11.711
# 1            0.412   0.276          0.000372    7    0.0955   -11.711
# 2            0.412   0.276          0.000372    7    0.0955   -11.711
# 3            0.667   0.599          0.000000    0    0.1070    -8.894
# 4            0.735   0.820          0.057200    2    0.0983    -8.554
# ...            ...     ...               ...  ...       ...       ...
# 5095         0.767   0.330          0.758000    5    0.5970   -12.559
# 5096         0.571   0.573          0.000009   10    0.3310    -4.533
# 5097         0.628   0.690          0.000000    8    0.1120    -5.828
# 5098         0.206   0.810          0.064400    9    0.0855    -6.492
# 5099         0.635   0.472          0.000000    8    0.1170    -3.869
#
#       audio_mode  speechiness    tempo  time_signature  audio_valence
# 0              1       0.0296   90.781               4         0.2140
# 1              1       0.0296   90.781               4         0.2140
# 2              1       0.0296   90.781               4         0.2140
# 3              1       0.0291  127.935               4         0.9710
# 4              1       0.0494  135.586               4         0.8590
# ...          ...          ...      ...             ...            ...
# 5095           0       0.0429  121.901               3         0.1950
# 5096           1       0.0383   96.122               4         0.0542
# 5097           1       0.0511  179.911               4         0.6620
# 5098           1       0.0423  163.552               4         0.1550
# 5099           0       0.5110  174.008               4         0.3730
#
# [5100 rows x 18 columns]

# %%
matched_df.to_csv('../Resources/matched_df.csv',index=False)

# %%
matched_df = pd.read_csv('../Resources/matched_df.csv')

# %%
matched_df = matched_df.drop(columns=['Song_List_Index','index'])
matched_df
# Out:
#                                      Song_Name  \
# 0                                  wooly bully
# 1                            youre only lonely
# 2                              only the lonely
# 3     i cant help myself sugar pie honey bunch
# 4                   i cant get no satisfaction
# ...                                        ...
# 5095                                      here
# 5096                                     waves
# 5097                                 el perdon
# 5098                             night changes
# 5099                              back to back
#
#                                   Matched_Name  Ratio_Value  \
# 0                                  only lonely           64
# 1                                  only lonely           79
# 2                                  only lonely           85
# 3     i cant help myself sugar pie honey bunch          100
# 4                   i cant get no satisfaction          100
# ...                                        ...          ...
# 5095                                     where           89
# 5096                                     waves          100
# 5097                                 el perdón           89
# 5098                               dont change           75
# 5099                              back to back          100
#
#                                          song_name  acousticness  \
# 0                                      Only Lonely      0.898000
# 1                                      Only Lonely      0.898000
# 2                                      Only Lonely      0.898000
# 3     I Can't Help Myself (Sugar Pie, Honey Bunch)      0.245000
# 4                    (I Can't Get No) Satisfaction      0.000380
# ...                                            ...           ...
# 5095                                         where      0.760000
# 5096                                         Waves      0.039100
# 5097                                     El Perdón      0.446000
# 5098                                  Don't Change      0.000059
# 5099                                  Back To Back      0.008980
#
#       danceability  energy  instrumentalness  key  liveness  loudness  \
# 0            0.412   0.276          0.000372    7    0.0955   -11.711
# 1            0.412   0.276          0.000372    7    0.0955   -11.711
# 2            0.412   0.276          0.000372    7    0.0955   -11.711
# 3            0.667   0.599          0.000000    0    0.1070    -8.894
# 4            0.735   0.820          0.057200    2    0.0983    -8.554
# ...            ...     ...               ...  ...       ...       ...
# 5095         0.767   0.330          0.758000    5    0.5970   -12.559
# 5096         0.571   0.573          0.000009   10    0.3310    -4.533
# 5097         0.628   0.690          0.000000    8    0.1120    -5.828
# 5098         0.206   0.810          0.064400    9    0.0855    -6.492
# 5099         0.635   0.472          0.000000    8    0.1170    -3.869
#
#       audio_mode  speechiness    tempo  time_signature  audio_valence
# 0              1       0.0296   90.781               4         0.2140
# 1              1       0.0296   90.781               4         0.2140
# 2              1       0.0296   90.781               4         0.2140
# 3              1       0.0291  127.935               4         0.9710
# 4              1       0.0494  135.586               4         0.8590
# ...          ...          ...      ...             ...            ...
# 5095           0       0.0429  121.901               3         0.1950
# 5096           1       0.0383   96.122               4         0.0542
# 5097           1       0.0511  179.911               4         0.6620
# 5098           1       0.0423  163.552               4         0.1550
# 5099           0       0.5110  174.008               4         0.3730
#
# [5100 rows x 16 columns]

# %%
# Import billboard_df to merge with high_ratio df

billboard_df = pd.read_csv('../Resources/billboard_df.csv')
billboard_df
# Out:
#       Rank                                      Song  \
# 0        1                               wooly bully
# 1        2  i cant help myself sugar pie honey bunch
# 2        3                i cant get no satisfaction
# 3        4                       you were on my mind
# 4        5              youve lost that lovin feelin
# ...    ...                                       ...
# 5095    96                                 el perdon
# 5096    97                                 she knows
# 5097    98                             night changes
# 5098    99                              back to back
# 5099   100                     how deep is your love
#
#                               Artist  Year  \
# 0      sam the sham and the pharaohs  1965
# 1                          four tops  1965
# 2                 the rolling stones  1965
# 3                            we five  1965
# 4             the righteous brothers  1965
# ...                              ...   ...
# 5095  nicky jam and enrique iglesias  2015
# 5096          neyo featuring juicy j  2015
# 5097                   one direction  2015
# 5098                           drake  2015
# 5099     calvin harris and disciples  2015
#
#                                                  Lyrics  Source  \
# 0     sam the sham miscellaneous wooly bully wooly b...     3.0
# 1      sugar pie honey bunch you know that i love yo...     1.0
# 2                                                           1.0
# 3      when i woke up this morning you were on my mi...     1.0
# 4      you never close your eyes anymore when i kiss...     1.0
# ...                                                 ...     ...
# 5095  enrique iglesias dime si es verdad me dijeron ...     3.0
# 5096                                                NaN     NaN
# 5097   going out tonight changes into something red ...     1.0
# 5098   oh man oh man oh man not againyeah i learned ...     1.0
# 5099   i want you to breathe me in let me be your ai...     1.0
#
#                                     fuzzy_name                    fuzzy_artist
# 0                                  wooly bully   sam the sham and the pharaohs
# 1     i cant help myself sugar pie honey bunch                       four tops
# 2                   i cant get no satisfaction              the rolling stones
# 3                          you were on my mind                         we five
# 4                 youve lost that lovin feelin          the righteous brothers
# ...                                        ...                             ...
# 5095                                 el perdon  nicky jam and enrique iglesias
# 5096                                 she knows          neyo featuring juicy j
# 5097                             night changes                   one direction
# 5098                              back to back                           drake
# 5099                     how deep is your love     calvin harris and disciples
#
# [5100 rows x 8 columns]

# %%
# Drop unnecessary columns before merging, only want the rank, year, and name (for matching)

billboard_df = billboard_df.drop(columns=['Song','Artist','Lyrics','Source','fuzzy_artist'])
billboard_df = billboard_df.rename(columns={'fuzzy_name':'Billboard Song Name'})
billboard_df
# Out:
#       Rank  Year                       Billboard Song Name
# 0        1  1965                               wooly bully
# 1        2  1965  i cant help myself sugar pie honey bunch
# 2        3  1965                i cant get no satisfaction
# 3        4  1965                       you were on my mind
# 4        5  1965              youve lost that lovin feelin
# ...    ...   ...                                       ...
# 5095    96  2015                                 el perdon
# 5096    97  2015                                 she knows
# 5097    98  2015                             night changes
# 5098    99  2015                              back to back
# 5099   100  2015                     how deep is your love
#
# [5100 rows x 3 columns]

# %%
# Join dataframes on index

composite_df = matched_df.join(billboard_df,how='inner')

# %%
composite_df
# Out:
#                                      Song_Name  \
# 0                                  wooly bully
# 1                            youre only lonely
# 2                              only the lonely
# 3     i cant help myself sugar pie honey bunch
# 4                   i cant get no satisfaction
# ...                                        ...
# 5095                                      here
# 5096                                     waves
# 5097                                 el perdon
# 5098                             night changes
# 5099                              back to back
#
#                                   Matched_Name  Ratio_Value  \
# 0                                  only lonely           64
# 1                                  only lonely           79
# 2                                  only lonely           85
# 3     i cant help myself sugar pie honey bunch          100
# 4                   i cant get no satisfaction          100
# ...                                        ...          ...
# 5095                                     where           89
# 5096                                     waves          100
# 5097                                 el perdón           89
# 5098                               dont change           75
# 5099                              back to back          100
#
#                                          song_name  acousticness  \
# 0                                      Only Lonely      0.898000
# 1                                      Only Lonely      0.898000
# 2                                      Only Lonely      0.898000
# 3     I Can't Help Myself (Sugar Pie, Honey Bunch)      0.245000
# 4                    (I Can't Get No) Satisfaction      0.000380
# ...                                            ...           ...
# 5095                                         where      0.760000
# 5096                                         Waves      0.039100
# 5097                                     El Perdón      0.446000
# 5098                                  Don't Change      0.000059
# 5099                                  Back To Back      0.008980
#
#       danceability  energy  instrumentalness  key  liveness  loudness  \
# 0            0.412   0.276          0.000372    7    0.0955   -11.711
# 1            0.412   0.276          0.000372    7    0.0955   -11.711
# 2            0.412   0.276          0.000372    7    0.0955   -11.711
# 3            0.667   0.599          0.000000    0    0.1070    -8.894
# 4            0.735   0.820          0.057200    2    0.0983    -8.554
# ...            ...     ...               ...  ...       ...       ...
# 5095         0.767   0.330          0.758000    5    0.5970   -12.559
# 5096         0.571   0.573          0.000009   10    0.3310    -4.533
# 5097         0.628   0.690          0.000000    8    0.1120    -5.828
# 5098         0.206   0.810          0.064400    9    0.0855    -6.492
# 5099         0.635   0.472          0.000000    8    0.1170    -3.869
#
#       audio_mode  speechiness    tempo  time_signature  audio_valence  Rank  \
# 0              1       0.0296   90.781               4         0.2140     1
# 1              1       0.0296   90.781               4         0.2140     2
# 2              1       0.0296   90.781               4         0.2140     3
# 3              1       0.0291  127.935               4         0.9710     4
# 4              1       0.0494  135.586               4         0.8590     5
# ...          ...          ...      ...             ...            ...   ...
# 5095           0       0.0429  121.901               3         0.1950    96
# 5096           1       0.0383   96.122               4         0.0542    97
# 5097           1       0.0511  179.911               4         0.6620    98
# 5098           1       0.0423  163.552               4         0.1550    99
# 5099           0       0.5110  174.008               4         0.3730   100
#
#       Year                       Billboard Song Name
# 0     1965                               wooly bully
# 1     1965  i cant help myself sugar pie honey bunch
# 2     1965                i cant get no satisfaction
# 3     1965                       you were on my mind
# 4     1965              youve lost that lovin feelin
# ...    ...                                       ...
# 5095  2015                                 el perdon
# 5096  2015                                 she knows
# 5097  2015                             night changes
# 5098  2015                              back to back
# 5099  2015                     how deep is your love
#
# [5100 rows x 19 columns]

# %%
composite_df.to_csv('../Resources/composite_df.csv',index=False)
